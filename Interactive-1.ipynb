# %% [markdown]
# Conectado a .venv (3.12.10) (Python 3.12.10)

# %%
import comm


comm
# Out:
# <module 'comm' from 'c:\\Users\\dilan\\OneDrive\\Documentos\\GitHub\\GHOSTKRAKEN\\.venv\\Lib\\site-packages\\comm\\__init__.py'>

# %%
import comm


comm
# Out:
# <module 'comm' from 'c:\\Users\\dilan\\OneDrive\\Documentos\\GitHub\\GHOSTKRAKEN\\.venv\\Lib\\site-packages\\comm\\__init__.py'>

# %%
import comm


comm
# Out:
# <module 'comm' from 'c:\\Users\\dilan\\OneDrive\\Documentos\\GitHub\\GHOSTKRAKEN\\.venv\\Lib\\site-packages\\comm\\__init__.py'>
