# %% [markdown]
# Conectado a .venv (3.12.10) (Python 3.12.10)

# %%
import comm


comm
# Out:
# <module 'comm' from 'C:\\Users\\dilan\\AppData\\Roaming\\Python\\Python312\\site-packages\\comm\\__init__.py'>

# %%
import comm


comm
# Out:
# <module 'comm' from 'C:\\Users\\dilan\\AppData\\Roaming\\Python\\Python312\\site-packages\\comm\\__init__.py'>
